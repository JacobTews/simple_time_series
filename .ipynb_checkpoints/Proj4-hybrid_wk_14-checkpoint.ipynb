# %% [markdown]
# # Proj 4 - Time series analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Load Data

# %%
df=pd.read_csv('store_sales_small.csv', parse_dates=["Order Date"])
# df.head(20)

# %% [markdown]
# ### Predict store sales

# %% [markdown]
# #### Set a time feature for linear regression (remember though there are some missing dates)

# %%
start = pd.Timestamp(2014, 1, 3)
df['day_num'] = df['Order Date'].apply(lambda x: int((x - start).days))

# %% [markdown]
# Note: Max value for Sales column is 10142.354 and min value is 1.788, so RF will not estimate outside those bounds

# %% [markdown]
# #### First, simple linear regression as baseline

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['day_num'], df['Sales'], shuffle=False, random_state=22, test_size=0.2)

# Since we only have a single feature, the array needs to be reshaped to use in a sklearn clf
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
# Import linear regression and metrics
from sklearn.linear_model import LinearRegression as lr
from sklearn.metrics import mean_squared_error, r2_score

# Create and fit the regressor
reg = lr()
reg.fit(df['day_num'].values.reshape(-1,1), df['Sales'])

# Make predictions using the test set
test_preds = reg.predict(X_test)

# The coefficients
print("Coefficient: \n", reg.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, test_preds))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination (R^2 score): %.2f" % r2_score(y_test, test_preds))
# Out:
# Coefficient:
#  [0.31372149]
# Mean squared error: 1071008.80
# Coefficient of determination (R^2 score): 0.01

# %% [markdown]
# * A straight linear regression is a pretty weak model!

# %%
# Plot regression line
import matplotlib.ticker as ticker

preds = reg.predict(df['day_num'].values.reshape(-1,1))

fig, ax = plt.subplots(figsize=(30, 15), facecolor='white')
plt.plot(df['day_num'], df['Sales'], color="grey", linewidth=0.7)
plt.plot(df['day_num'], preds, color="blue", linewidth=3)

ax.set_facecolor('white')
ax.grid(False)
ax.set_title('Sales show a slight upward trend over the time period studied', size=30, loc='left')
ax.set_xlabel('Day number (begins at 3 Jan 2014, ends 30 Dec 2017)')
ax.set_ylabel('Sales')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('$ %d'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
 
# # these are matplotlib.patch.Patch properties
# props = dict(boxstyle='round', facecolor='wheat')

# # place a text box in upper left in axes coords
# ax.text(0.05, 0.95, 'Slight upward trend', transform=ax.transAxes, fontsize=14,
#         verticalalignment='top', bbox=props)

ax.annotate('Sales show slight upward trend', xy=(500, 1000), color='blue', bbox=dict(fc="white", ec="blue", lw=3, pad=7))
# plt.xticks(())
# plt.yticks(())

# plt.show()
plt.savefig('viz/rerun_linear_regression.png', transparent=True)

# %% [markdown]
# #### Are lags predictive?  If so add them

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Calculate ACF and PACF upto 50 lags
# acf_50 = acf(df.value, nlags=50)
# pacf_50 = pacf(df.value, nlags=50)

# Draw Plot
fig, axes = plt.subplots(1,2,figsize=(20,5), dpi= 100)
plot_acf(df['Sales'].tolist(), lags=100, ax=axes[0])
plot_pacf(df['Sales'].tolist(), lags=100, ax=axes[1])
for ax in axes.flat:
    ax.set(xlabel='n_lags', ylabel='correlation')
plt.tight_layout()
# Out:
# C:\Users\00986562\Anaconda3\envs\data301\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# * It seems as though lags have limited predictive value; a 50-day lag seems to be the most correlated, interestingly, followed by a 1-day lag. Doesn't hurt to add those, I suppose!

# %%
def add_lags(df, lag_vals):
    for val in lag_vals:
        col_name = f'lag_{val}'
        print(f'Adding column: {col_name}')
        df[col_name] = df['Sales'].shift(val)

add_lags(df, [1, 50])
# Out:
# Adding column: lag_1
# Adding column: lag_50

# %% [markdown]
# #### Create a model

# %%
class BoostedHybrid:
    '''
    Runs model_1 on data, then runs model_2 on residuals of model_1
    In practice model_1 detrends the data then model_2 uses a ML algorithm to forcast target values on detrended data
    '''
    def __init__(self, model_1, model_2):
        self.model_1 = model_1
        self.model_2 = model_2
        # self.num_lags = lags

    def fit(self, X_1, X_2, y):
        '''
        X_1 dataset for linear regression(uses column 'Order Date')
        X_2 dataset for random forest ('all other dataset columns')
        y  target ('Sales')
        '''
        self.train_size = len(X_1)
        
        #fit the first model on train portion of dataset
        self.model_1.fit(X_1, y) # train model 1
        
        #generate residuals for entire dataset (only used to calculate lags)
        self.y_resid = y - self.model_1.predict(X_1)
        
        # #compute and add the lags to X_2
        # X_2['y_resid']=self.y_resid
        # for i in range(1,self.num_lags+1):
        #     X_2['Lag_'+str(i)]=X_2.y_resid.shift(i)
        X_2.dropna(inplace=True)  #alas goodbye to some rows
        # # display(X_2)
        
        #save these residuals for later
        self.y_resid = X_2.y_resid
        
        #drop target from training data
        X_2.drop(columns=['y_resid'], inplace=True, axis=1)  #this gets rid of target value, so model only sees past lags
        # display(X_2)
        
        #fit the second model on residuals from first model, just the train data part
        self.model_2.fit(X_2.iloc[0:self.train_size,:], self.y_resid[:self.train_size])
        self.X_1 = X_1
        self.X_2 = X_2
        
    def predict(self, X_1, X_2, y):
        #to get a prediction add Model_1's prediction to Model_2's prediction
        #generate residuals for dataset
        X_2['preds'] = self.model_1.predict(X_1)
        X_2['y_resid'] = y - X_2['preds'] 
        
        # #compute and add the lags to X_2
        # for i in range(1, self.num_lags+1):
        #     X_2['Lag_'+str(i)]=X_2.y_resid.shift(i)

        X_2.dropna(inplace=True)  #alas goodbye to some rows
        # display(X_2)
       
        #get the X_1 preds
        y_pred1 = X_2['preds']
        
        #drop columns that are not used for model_2
        X_2.drop(columns=['preds', 'y_resid'], inplace=True)
        y_pred2 = self.model_2.predict(X_2)
        return(y_pred1 + y_pred2)

# %% [markdown]
# #### What is your models Rsquared with just a plain hybrid model

# %%
# Partitioning the dataset: get target value, the training set for linear regression, and the training set for random forest
y = df['Sales']
# y_test = 
X_1 = df.loc[:,['day_num']]
X_2 = df.loc[:,['day_num']]
# X_2=df.loc[:,['Time']]
# display(y)
# display(X_1)
# display(X_2)

# %%
from sklearn.ensemble import RandomForestRegressor as rfr

# Create instance of BoostedHybrid model
hm = BoostedHybrid(model_1=lr(), model_2=rfr(random_state=22))

# Fit the model
hm.fit(X_1, X_2, y)

# Predict
preds = hm.predict()

# Check R^2
print(f'(R^2 score): {r2_score(y[-len(preds):], preds)}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 7>()
#       4 hm = BoostedHybrid(model_1=lr(), model_2=rfr(random_state=22))
#       6 # Fit the model
# ----> 7 hm.fit(X_1, X_2, y)
#       9 # Predict
#      10 preds = hm.predict()
#
# Input In [9], in BoostedHybrid.fit(self, X_1, X_2, y)
#      29 X_2.dropna(inplace=True)  #alas goodbye to some rows
#      30 # # display(X_2)
#      31
#      32 #save these residuals for later
# ---> 33 self.y_resid = X_2.y_resid
#      35 #drop target from training data
#      36 X_2.drop(columns=['y_resid'], inplace=True, axis=1)  #this gets rid of target value, so model only sees past lags
#
# File ~\Anaconda3\envs\data301\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'y_resid'

# %% [markdown]
# * Wow, that's a terrible model, much worse than simply using linear regression by itself. Perhaps the random forest needs tuning?

# %%
import optuna
from sklearn.model_selection import cross_val_score

# Silence the optuna output except for errors
optuna.logging.set_verbosity(optuna.logging.WARNING)

# First tune the random forest
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 5, 205, step=10)
    max_depth = trial.suggest_int('max_depth', 1, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    
    clf = rfr(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    
    return cross_val_score(clf, X_2, y, n_jobs=-1).mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Then pass the tuned RF into the hybrid model
model_2 = rfr(random_state=22, **study.best_params)

hm_with_tuned_rf = BoostedHybrid(model_1=lr(), model_2=model_2)

# Fit the model
hm_with_tuned_rf.fit(X_1, X_2, y)

# Predict
tuned_preds = hm_with_tuned_rf.predict()

# Check R^2
print(f'R^2 score: {r2_score(y[-len(tuned_preds):], tuned_preds)}')

# %% [markdown]
# Pre-tuned R^2: -0.6921898714595429
#
# Post-tuned R^2: -0.4476048645094961
#
# Better, but not a significant difference ha!

# %% [markdown]
# #### What is your model's R-squared score with the lags

# %%
df.columns

# %%
X_2_lags = df.loc[:,['day_num', 'lag_1', 'lag_50']].dropna()

# %%
y_lags = y[-len(X_2_lags):]

# %%
# First tune the random forest
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 5, 205, step=10)
    max_depth = trial.suggest_int('max_depth', 1, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    
    clf = rfr(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    
    return cross_val_score(clf, X_2_lags, y_lags, n_jobs=-1).mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Then pass the tuned RF into the hybrid model
model_2 = rfr(random_state=22, **study.best_params)

hm_with_lags = BoostedHybrid(model_1=lr(), model_2=model_2)

# Fit the model
hm_with_lags.fit(X_1, X_2_lags, y)

# Predict
lags_preds = hm_with_lags.predict()

# Check R^2
print(f'R^2 score: {r2_score(y[-len(lags_preds):], lags_preds)}')

# %% [markdown]
# * With lags, we get significantly better performance, but that's mostly because the plain hybrid model was *so terrible*.

# %% [markdown]
# #### What is your models Rsquared if you add additional features (holidays, back to school)

# %% [markdown]
# ##### Going on the assumption this store is based in the US, let's add some features

# %% [markdown]
# * Weekends

# %%
# Weekends
df['is_weekend'] = df['Order Date'].apply(lambda x: 1 if x.dayofweek in [5, 6] else 0)

# %% [markdown]
# * Holidays

# %%
from pandas.tseries import holiday

# %%
cal = holiday.AbstractHolidayCalendar(rules=holiday.USFederalHolidayCalendar.rules)
hols = np.array(cal.holidays())

# %%
df['is_holiday'] = df['Order Date'].isin(hols).astype(int)

# %%
# df['is_holiday'].value_counts()
# df.tail(10)

# %% [markdown]
# Wow...the documentation on the pandas holiday package is really limited! That took me more than an hour to get it to work...

# %% [markdown]
# * Back-to-school...?

# %%
# Let's define "back-to-school shopping" as the month of August, for the sake of simplicity
df['is_bts'] = df['Order Date'].apply(lambda x: 1 if x.month == 8 else 0)

# %% [markdown]
# ##### Modeling with added features

# %%
X_2_feats = df.loc[:, ['day_num', 'lag_1', 'lag_50', 'is_weekend', 'is_holiday', 'is_bts']].dropna()

# %%
# First tune the random forest
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 5, 205, step=10)
    max_depth = trial.suggest_int('max_depth', 1, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    
    clf = rfr(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    
    return cross_val_score(clf, X_2_feats, y_lags, n_jobs=-1).mean()

feat_study = optuna.create_study(direction='maximize')
feat_study.optimize(objective, n_trials=100)

# %%
# Then pass the tuned RF into the hybrid model
model_2 = rfr(random_state=22, **feat_study.best_params)

hm_with_feats = BoostedHybrid(model_1=lr(), model_2=model_2)

# Fit the model
hm_with_feats.fit(X_1, X_2_feats, y)

# Predict
feats_preds = hm_with_feats.predict()

# Check R^2
print(f'R^2 score: {r2_score(y[-len(feats_preds):], feats_preds)}')

# %%
hm_with_feats_no_tuning = BoostedHybrid(model_1=lr(), model_2=rfr(random_state=22))

# Fit the model
hm_with_feats_no_tuning.fit(X_1, X_2_feats, y)

# Predict
feats_no_tune_preds = hm_with_feats_no_tuning.predict()

# Check R^2
print(f'R^2 score: {r2_score(y[-len(feats_no_tune_preds):], feats_no_tune_preds)}')

# %%
start = -len(feats_no_tune_preds)

fig, ax = plt.subplots(figsize=(15, 10), facecolor='white')
plt.plot(df['day_num'][start:], y[start:], linewidth=0.7, color='grey', label='Actual sales')
plt.plot(df['day_num'][start:], feats_no_tune_preds, linewidth=0.7, color='blue', label='Predicted sales')

ax.set_facecolor('white')
ax.grid(False)
ax.set_title('Predictive model loses steam', loc='left', size=30)
ax.set_xlabel('Day number (0 begins at 3 Jan 2014, ends 30 Dec 2017)', labelpad=15)
ax.set_ylabel('Sales')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('$ %d'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.annotate('Things are OK until here...',
            xy=(1388, 1000),
            xytext=(1355, 3000),
            color='orange',
            bbox=dict(fc="white", ec="orange", lw=3, pad=7, alpha=0.7),
            arrowprops=dict(facecolor='orange', shrink=0.05))
# plt.xticks(())
# plt.yticks(())
plt.legend(facecolor='white', loc='upper left')

# plt.show()
plt.savefig('viz/best_model_preds.png', transparent=True)

# %% [markdown]
# #### What is the permutation importance for your model?

# %%
from sklearn.inspection import permutation_importance

perm_x = (X_1[-len(X_2_feats):], X_2_feats)

result = permutation_importance(
    estimator=hm_with_feats_no_tuning,
    X=perm_x,
    y=y,
    n_repeats=10,
    random_state=22,
    n_jobs=-1,
    scoring='r2'
)

hybrid_importances = pd.Series(result.importances_mean, index=X_2_feats.columns)

# %%
forest_importances.sort_values(inplace=True)

# %%
colors = []

for i in range(32):
    colors.append('lightgray')
    
for i in range(11):
    colors.append('steelblue')

# %%
fig, ax = plt.subplots(figsize=(10, 15))
# plt.barh(forest_importances, width=2, yerr=result.importances_std, color=colors)
bars = ax.barh(forest_importances.index, forest_importances, color=colors)

# labels = []
# for i in range(11):
#     labels.append(forest_importances[i])

#     # set the bar label
#     # ax.bar_label(c, labels=labels, fontsize=8, padding=3)

_ = ax.bar_label(bars, labels=labels, padding=4, fmt='%.3f')
# forest_importances.plot.barh(yerr=result.importances_std, ax=ax)
_ = ax.set_title("Feature importances")
_ = ax.set_ylabel("Mean accuracy decrease")
ax.set_facecolor('whitesmoke')
ax.grid(visible=True)
fig.tight_layout()
plt.show()
fig.savefig('viz/rf_feature_importances.png')

# %% [markdown]
# #### The top 10 issues which influence voter decisions:
# 1. CC16_351I : Opinion on ACA
# 2. CC16_302 : Perception of direction of economy
# 3. CC16_331_7 : Immigration policy
# 4. Racial identity, particularly whether the voter identifies as white or black
# 5. CC16_351K : Raise federal minimum wage to $12?
# 6. CC16_333d : Enforcement of Clean Air and Clean Water acts
# 7. CC16_330d : Ban assault rifles?
# 8. CC16_307 : Perception of police
# 9. CC16_332a : Abortion
# 10. CC16_335 : Gay marriage
